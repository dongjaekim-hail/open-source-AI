# %% [markdown]
# # 소개
#
# ## Python 과 Jupyter
#
# 파이썬 (python) 은 원래 인터프리터 언어입니다. 인터프리터 언어란, 대화형이라는 그 말 뜻 그대로 한 번에 한 줄의 코드를 실행하고 그 코드의 실행 결과를 바로 확인하는 형태의 코드를 의미합니다.
#
# 아마도 여러분들은 이런 인터프리터의 형태로 파이썬을 활용하는 일이 그다지 많지 않습니다. 디버깅을 제외하고는 .py 확장자의 파일을 눌러서 실행하죠! 이런 파일들은 다른 절차형 프로그래밍 언어처럼 순서대로 실행이 됩니다.
#
# 상호작용을 통해 (interative) 파이썬을 인터프리터 형태로 활용할 수 있도록 만들어 진 것이 ipython 이라고 하는 쉘 (shell) 입니다. 여기서는 실행하는 코드의 line number 가 직혀나오기 때문에 어떤 코드를 실행했을 때 어떤 아웃풋이 나오는지를 직관적으로 확인할 수 있습니다. 그러나 이것은 파이썬에 제한적이기 때문에, 새로운 형태가 제안됩니다.
#
# 그게 바로 jupyter입니다.
#
# 파이썬이 주로 쓰이는 분야중에 하나가 데이터사이언스 입니다. 이 분야에서 사용하는 다른 유명 언어로는 R이 있구요, matlab을 대체하는 또 다른 언어로 Julia가 있습니다.
#
# (R 은 통계 분석에 정확하고 다양한 기능이 있다는 장점이 있구요, julia는 machine learning 류의 분석이 빠르다는 장점이 있습니다.)
#
# julia + python + R 을 합쳐서 jupyter라고 부르는 새로운 인터랙티브 대화형 쉘로 만들어진 것이 jupyter 이고 colab 은 그 문법을 그대로 활용합니다!
#
# ## Colab이란?
#
# colab 은 클라우드 컴퓨팅으로 만들어진 jupyter notebook 입니다. 저장공간을 google drive 와 연결할 수 있기 때문에 큰 용량의 데이터를 처리하기에도 적절합니다.
#
# ### 대충 어떤 식으로 구현되나?
#
# 어러분이 colab을 열면 해당 jupyter notebook 파일이 클라우드 (즉, 서버) 에서 열립니다. 서버에서 virtual box와 같은 어떤 프로그램(도커)을 통해서 가상의 리눅스 컴퓨터를 여러분의 jupyter notebook 에 연결 시켜줍니다.
#
# 여러분이 이 노트북에서 활용하고 하는 모든 연산은 클라우드에 만들어진 가상의 리눅스 컴퓨터를 활용하여 이루어집니다.
#
# 기본적으로 colab에는 여러분들이 주로 활용하는 프로그램들이 설치되어있습니다. 대표적인 것들이 python 의 library 들입니다. pytorch, tensorflow 같은 것들은 당연하고, opencv등 유용하게 활용하는 library들이 미리 설치되어 있습니다.
#
# 어떤 library가 설치되어있는지는 `!pip list` 를 실행하면 알 수 있습니다. 이는 jupyter notebook 실행을 통해서 실제로 연결되어있는 리눅스 컴퓨터의 terminal 에 명령어를 전달하는 방법입니다. `!pwd` 라고 하면 현재의 working directory 를 알려주게 되겠죠.
#
# **물론 무제한으로 쓸 수는 없습니다!**
#
# 최대 12시간의 사용시간을 보여줍니다.... 라고 합니다만, 유료결제를 하면 이 한계를 무시하고 계속 쓸 수 있죠!....라고 합니다만 AI 학회 due day 시기에는 12시간 이전에 끊기고, 유료결제해도 끊기기도 합니다.
#
# 아까도 말했지만 세션이 끊기는게 뭐냐면, 결국 여러분이 연결된 가상 리눅스 컴퓨터가 사라지는 것과 동일합니다. 로컬로 저장한 데이터들이 날라가게 됩니다...
#
# 그래서 Google drive 동기화를 잘 쓰세요. 여러분 Google Suite 있잖아요 (용량을 과다하게 사용할 시 학교에서 연락이 갈 수 있습니다.)
#
#
# ## 중요한 기능 목록
#
# 알아 두면 좋은 기능들이 정말 많지만, 몇 가지만 알면 좋을 것 같아요.
#
# - cpu와 gpu의 런타임으로 변경할 수 있습니다.
# - 데이터 로딩:
#   - Google Drive에 연결할 수 있습니다!
#   - 여러분 local computer의 것도 활용할 수 있습니다...만
# - jupyter의 용법을 그대로 활용합니다.
# - Markdown 문법의 텍스트 블록과 코드 블록을 활용합니다.
# - Latex 문법의 수식 입력을 제공합니다.
#
# 이것에 대해서 하나하나 봅시다.

# %% [markdown]
# # 1. 런타임 변경
#
# 위의 툴바 런타임>런타임 유형 변경>하드웨어 가속기에서 GPU 또는 None (CPU) 선택> re캡챠 (신호등 찾기 등)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1.1. GPU 연결 확인?
#
# `!nvcc --version` 실행 시 아래와 같이 Cuda compiler driver 나오면 GPU 를 사용할 수 있는 드라이버 정보가 나옵니다.

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# `!nvidia-smi` 실행 시 현재 연결된 GPU에 대한 세부정보를 볼수 있습니다.
#
# **중요한 것은** *이 창이 안뜬다면 GPU 연결이 제대로 되지 않았다는 것 입니다.*
#
#
# Name 에 `Tesla T4` 라고 되어있고, 더 중요한 것은 GPU의 RAM, 즉 VRAM이 `15109MiB` 라고 되어있네요. 네트워크 사이즈에 따라서 이 부분이 매우 중요할 수 있습니다.
#
# 가끔 다른 것도 걸려요.

# %%
# !nvidia-smi
# Out:
# Thu Sep 15 08:53:10 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8    12W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# > CUDA는 뭔가요?
# >> CUDA는 nvidia 그래픽카드에서 딥러닝을 하기 위해서 (신경망) 필요한 드라이버 입니다. 따라서 radeon, 혹은 맥북 m1 등의 노트북에서는 활용할 수 없습니다.
# >
# >> nvidia-smi 는 nvida 그래픽카드의 작업관리자입니다. 여기에 실행중인 딥러닝 프로그램이 있다면 보여집니다. 일반적으로 없겠죠?

# %% [markdown]
# ## 1.2. CPU 연결 되었을때
#
# `!nvcc --version` 실행 시 아래와 같이 GPU 연결과 동일하게 CUDA driver는 있지만...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# `!nvidia-smi` 실행 시 NVIDIA 드라이버랑 연결 할수 없다고 나옵니다.

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %% [markdown]
# > CUDA는 뭔가요?
# >> CUDA는 nvidia 그래픽카드에서 딥러닝을 하기 위해서 (신경망) 필요한 드라이버 입니다. 따라서 radeon, 혹은 맥북 m1 등의 노트북에서는 활용할 수 없습니다.
# >
# >> nvidia-smi 는 nvida 그래픽카드의 작업관리자입니다. 여기에 실행중인 딥러닝 프로그램이 있다면 보여집니다. 일반적으로 없겠죠?

# %% [markdown]
# ## 1.3. python 코드 내에서 확인하는 법
#
# 때로는 이렇게 `!`를 붙여 확인하는 것이 아니라 파이썬 코드 내에서 확인할 필요가 있습니다.
#
# 네트워크에 따라서 굳이 GPU를 쓰지 않아도 되는 경우가 종종 있기 때문에, 그냥 연결 가능한 디바이스를 쓰는 거죠.

# %%
# tensorflow 확인법
import tensorflow as tf
print(tf.test.is_gpu_available())
# pytorch 확인법
import torch
print(torch.cuda.is_available())
# Out:
# WARNING:tensorflow:From <ipython-input-3-bf766549b838>:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True
# True

# %% [markdown]
# # 2. 데이터 로딩
#
# ## 2.1. Google drive 연결

# %% [markdown]
# ### 2.1.1. 직접적으로 mount 하기
#
# 아시다시피 mount 는 usb 를 꽂는 것처럼 하드를 연결하는 걸 말합니다. 컴퓨터 조립같은 거 하면 자주 보게 되죠! 하드디스크를 새롭게 연결하고나서 usb 처럼 바로 뜨지 않고 mount 를 시켜줘야 (OS 시스템에 연결하는 작업) 해당 디스크를 사용할 수 있습니다.
#
# 여기서도 Google drive를 마운트 할겁니다. 왼쪽의 툴바에서 다음과 같이 연결합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 클릭하시면 다음과 같은 코드블럭이 현재 열린 colab jupyter 노트북에 삽입됩니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 실행하시고 시키는대로 하다보면 연결되고, 연결된 위치를 알려줍니다.
#
# 다시 왼쪽의 툴바를 보면 /content/drive 에 구글 드라이브가 연결된 것을 볼 수 있습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.1.2. 특정 파일 불러오기
#
# 마운트 해서 일일히 접근하는게 불편하다면 실제로 그 디렉토리에서 가져올 수 있습니다. 조금 복잡하고 귀찮으니까 그냥 마운트해서 쓰는 2.1.1. 의 방법을 추천드립니다.
# https://towardsdatascience.com/different-ways-to-connect-google-drive-to-a-google-colab-notebook-pt-1-de03433d2f7a

# %% [markdown]
# # 2.2. Local data 불러오기
#
# 창을 띄워 데이터를 가져옵니다.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9752230a-f0c8-42f9-9fd9-7f4e0ea30da8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9752230a-f0c8-42f9-9fd9-7f4e0ea30da8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-21dc3c638f66> in <module>
#       1 from google.colab import files
# ----> 2 uploaded = files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      39   """
#      40
# ---> 41   uploaded_files = _upload_files(multiple=True)
#      42   # Mapping from original filename to filename as saved locally.
#      43   local_filenames = dict()
#
# ...

# %% [markdown]
# # 3. jupyter의 용법
#
# 원래 jupyter 를 실행하려면 `pip install`을 통해서 주피터를 설치하고, cmd 혹은 터미널에서 `jupyter notebook`을 치고, 켜진 jupyter notebook 을 썼습니다.
#
# colab 도 기본적인 틀은 유사한데, 위의 방법대로 킨 jupyter notebook 과는 조금 많이 다릅니다. 여기서는 동잃한 것과 동일 하지 않은 것을 조금 알아보고, 실제로 우리가 필요로 하고 많이 쓰는 단축키에 대해서 알아봅시다.
#
# ## 3.1. CMD 혹은 터미널에 명령 전달하기
#
# `!명령어` 를 실행하면 `명령어`를 CMD 혹은 터미널에 실행한 것과 같은 결과를 보입니다.

# %%
# !ls

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ## 3.2. 단축키
#
# 원래 jupyter notebook 에서는 단축키를 많이 활용합니다. colab 으로 오면서 기존에 jupyter notebook 이 사용하는 단축키가 다른 키들과 겹칠 수 있기 때문에 약간의 변형이 있다는것만 주의! 그러나 기본적으로는 크게 다르지 않아요. 여기는 대표적으로 자주 쓰는 몇가지 단축키에 대해서만 서술합니다.
#
# `ctrl + M + B`
#
# `ctrl + M + A`
#
# `ctrl + M + M / Y`
#
# `ctrl + M + D`

# %% [markdown]
# # 4. Markdown 용법
#
# 그냥 어디 딴데서 배우십쇼. 이것까지 설명하기 좀 그렇네요
#
#
# ---
#
#
# ## 제목2
# ### 제목3
# #### 제목4
#
#
# ---
#
#
# - 항목1
#   - 항목1의 항목1
#   - 항목1의 항목2
# - 항목2
#
#
# ---
#
# - `**굵은 글씨**` **굵은 글씨**
# - `*기울인 글씨*` *기울인 글씨*

# %% [markdown]
# # 5. Latex
#
# $a_b^c$
#
# $\sum_{n=0}^N$
#
# $\int_0^\infty$
#
# $\frac{a}{b}$
#
# $\text{this is a text} \,\, $
# $y=f(x) \,\,\, \text{for} \,\,\, x>0$
#
# https://ko.overleaf.com/learn/latex/Mathematical_expressions
